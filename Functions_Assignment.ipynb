# %%
1) What is the difference between an function and a method in python.
Ans) A function is an independent block of code and a method is associated with
 an object. (e.g., list.append()).

2) Explain the concept of function arguments and parameter in python.
Ans) Parameters are placeholders in function definitions where as arguments are
actual values passed.

3) What are the different ways to define and call a function in python.
Ans) Use 'def', call by name and parentheses. For Example: def greet():
print('Hi') / greet().

4) What is the purpose of the 'return' statement in python.
Ans) Used to return a result from a function. For Example: return x + y.

5) What are iterators in python and how do they differ from iterables.
Ans) Iterables can be looped where as iterators implement __next__(). For Example: list is
iterable, iter(list) is iterator.

6) Explain the concept of generators in python and how they are defined.
Ans) Generators are functions using yield to produce values lazily. For Example: def gen(): yield 1

7) What are the advantages of using generators over regular functions in python.
Ans) Generator are memory efficient, lazy evaluation and have simple syntax.

8) What is lambda functions in python and when is it typically used.
Ans) Lambda function is an anonymous function for simple tasks. Example: lambda x: x*x

9) Explain the purpose and usage of the map() function in python.
Ans) It applies a function to all items in iterable. Example: map(str, [1,2])

10) What is the difference between map(), reduce() and filter() functions in python.
Ans) map() - Applies a function to each item in an iterable and returns a map object.
     reduce() - Repeatedly applies a function to reduce the iterable to a single value.
     Filter() -  Filters elements in an iterable for which the function returns true.

11) Using pen and paper write the internal mechanism for sum operation using reduce function on this given list [47,11,42,13]

# %% [markdown]
# ![WhatsApp Image 2025-07-19 at 12.08.28_a30fb250.jpg](data:image/jpeg;base64,...)

# %%
#1) Write a python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_even(numbers):
  return sum(num for num in numbers if num % 2 == 0)
print(sum_even([1,2,3,4,5,6,7]))
# Out:
# 12

# %%
#2) Create a python function that accepts a string and returns the reverse of the string.
def reverse_string(s):
  return s[::-1]
print(reverse_string('hello'))
# Out:
# olleh

# %%
#3) Implement a python function that takes a list of integers and returns a new list containing the squares of each number.
def square_numbers(numbers):
  return[num ** 2 for num in numbers]
print(square_numbers([1,2,3,4]))
# Out:
# [1, 4, 9, 16]

# %%
#4) Write a python code that checks if a given number is prime or not from 1 to 200.
def is_prime():
  if n <=1:
    return False
  for i in range(2, int(n**0.5) + 1):
      if n % i == 0:
        return False
        return True
for num in range(1,201):
  if is_prime(num):
    print(num, end="")    # please help me with this question
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-40-1996606946.py in <cell line: 0>()
#       8         return True
#       9 for num in range(1,201):
# ---> 10   if is_prime(num):
#      11     print(num, end="")
#
# TypeError: is_prime() takes 0 positional arguments but 1 was given

# %%
#5) Create an iterator class in python that generates the fibonacci sequence upto a specified number of terms.
class FibonacciIterator:
    def _init_(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a, self.b = 0, 1

    def _iter_(self):
        return self

    def _next_(self):
        if self.count >= self.max_terms:
            raise StopIteration
        result = self.a
        self.a, self.b = self.b, self.a + self.b
        self.count += 1
        return result

fib = FibonacciIterator(10)
for num in fib:
    print(num, end=" ")   # please help me with this question.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-44-969189355.py in <cell line: 0>()
#      17         return result
#      18
# ---> 19 fib = FibonacciIterator(10)
#      20 for num in fib:
#      21     print(num, end=" ")
#
# TypeError: FibonacciIterator() takes no arguments

# %%
#6) Write a generator function in python that yields the power of 2 upto a given exponent.
def powers_of_two(max_exponent):
    for i in range(max_exponent + 1):
        yield 2 ** i
for power in powers_of_two(5):
    print(power, end=" ")
# Out:
# 1 2 4 8 16 32

# %%
#7) Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_line_by_line(filename):
  with open(filename, 'r') as file:
        for line in file:
            yield line.strip()
for line in read_file_line_by_line('example.txt'):    # please help me with this question
  print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-52-2373971659.py in <cell line: 0>()
#       4         for line in file:
#       5             yield line.strip()
# ----> 6 for line in read_file_line_by_line('example.txt'):
#       7   print(line)
#
# /tmp/ipython-input-52-2373971659.py in read_file_line_by_line(filename)
#       1 #7) Implement a generator function that reads a file line by line and yields each line as a string.
#       2 def read_file_line_by_line(filename):
# ----> 3   with open(filename, 'r') as file:
#       4         for line in file:
#       5             yield line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %%
#8) Use a lambda function in python to sort a list of tuples based on the second element of each tuple.
def sort_tuples(tuples_list):
    return sorted(tuples_list, key=lambda x: x[1])
tuples = [(1, 3), (4, 1), (2, 2)]
print(sort_tuples(tuples))
# Out:
# [(4, 1), (2, 2), (1, 3)]

# %%
#9) Write a python program that uses map() to convert a list of temperatures from celcius to fahrenheit.
def celsius_to_fahrenheit(celsius_list):
    return list(map(lambda c: (c * 9/5) + 32, celsius_list))
celsius = [0, 10, 20, 30, 100]
print(celsius_to_fahrenheit(celsius))
# Out:
# [32.0, 50.0, 68.0, 86.0, 212.0]

# %%
#10) Create a python program that uses filter() to remove all the vowels from a given string.
def remove_vowels(s):
    vowels = "aeiouAEIOU"
    return ''.join(filter(lambda char: char not in vowels, s))
print(remove_vowels("Hello World"))
# Out:
# Hll Wrld

# %%
#11) Kindly refer it from the assignment pdf. Thank you
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]]

processed_orders = list(map(lambda order: (order[0], order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)), orders))
print(processed_orders)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
